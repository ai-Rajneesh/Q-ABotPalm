# %%
# !pip install google-generativeai

# %%
# !pip install langchain

# %%
from langchain.llms import GooglePalm

api_key = 'AIzaSyB587w1fO7bzIiiZpVoPcOo6mcbETeWlqQ'

raj_llm = GooglePalm(google_api_key=api_key, temperature=0.7)

# %%
poem = raj_llm('write a 4 line poem for my favourite laptop')
print(poem)
# Out:
# My favorite laptop
# Is a sleek and silver friend
# It's always there for me
# To help me with my work

# %%
email = raj_llm('write email requesting refund for flight ticket')
print(email)
# Out:
# Dear [Name of Airline],
#
# I am writing to request a refund for my flight ticket number [flight ticket number]. I am requesting a refund because I have to cancel my flight due to [reason for cancellation].
#
# I purchased my flight ticket on [date of purchase] for a total of [amount paid]. I am requesting a full refund of my ticket price.
#
# I understand that there are some restrictions on refunds, but I believe that my situation meets the criteria for a refund. I have attached a copy of my itinerary and a screenshot of my email confirmation.
#
# I would appreciate it if you could process my refund as soon as possible. My contact information is [email address] and [phone number].
#
# Thank you for your time and consideration.
#
# Sincerely,
# [Your name]

# %%
from langchain.chains import RetrievalQA

from langchain.embeddings import GooglePalmEmbeddings
from langchain.llms import GooglePalm

# %%
'''from langchain.document_loaders.csv_loader import CSVLoader
loader = CSVLoader(file_path='data.csv', source_column='rating')

# Store the loaded data in the 'data' variable
docs = loader.load()'''
# Out:
# "from langchain.document_loaders.csv_loader import CSVLoader\nloader = CSVLoader(file_path='data.csv', source_column='rating')\n\n# Store the loaded data in the 'data' variable\ndocs = loader.load()"

# %%
# !pip install InstructorEmbedding

# %%
# !pip install sentence-transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 28.8 MB/s eta 0:00:00
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=5815620d4caf70a5e72fb93dc2d27f1df66f37fb33c60d0bde84d3e9ed6483f2
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# ...

# %%
from langchain.embeddings import HuggingFaceInstructEmbeddings

embeddings = HuggingFaceInstructEmbeddings(model_name="hkunlp/instructor-large")

query_result = embeddings.embed_query('This is a test document.')
# Out:
# .gitattributes:   0%|          | 0.00/1.48k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/270 [00:00<?, ?B/s]
# 2_Dense/config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/3.15M [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/66.3k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.41k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/461 [00:00<?, ?B/s]
# load INSTRUCTOR_Transformer
# max_seq_length  512

# %%
len(query_result)
# Out:
# 768

# %%
type(query_result)
# Out:
# list

# %%
query_result[:5]
# Out:
# [0.01804392598569393,
#  -0.05097692087292671,
#  -0.0229482501745224,
#  0.01861584186553955,
#  0.02416592836380005]

# %%
# !pip install faiss-cpu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 86.6 MB/s eta 0:00:00
# ...

# %%
# !pip install PyPDF2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 4.9 MB/s eta 0:00:00
# ...
# 'pip install PyMuPDF\npip install pdfplumber'

# %%
# !pip install pdfplumber
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.0/49.0 kB 1.6 MB/s eta 0:00:00
# ...
#   Using cached pdfminer.six-20221105-py3-none-any.whl (5.6 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 36.1 MB/s eta 0:00:00
# ...

# %%
# !pip install PyMuPDF
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 38.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.6/30.6 MB 20.9 MB/s eta 0:00:00
# ...

# %%
from langchain.document_loaders import PDFPlumberLoader

loader = PDFPlumberLoader("/content/CNN.pdf")
docs = loader.load()

# %%
from langchain.embeddings import HuggingFaceInstructEmbeddings
from langchain.vectorstores import FAISS
embeddings = HuggingFaceInstructEmbeddings(model_name="hkunlp/instructor-large")

# Create an instance of FAISS vector store and index the documents
vectordb = FAISS.from_documents(documents=docs, embedding=embeddings)
# Out:
# load INSTRUCTOR_Transformer
# max_seq_length  512

# %%
retriever = vectordb.as_retriever()

# %%
rdocs = retriever.get_relevant_documents("How CNN works?")
rdocs
# Out:
# [Document(page_content='How CNN Works?\nStep 1, Input Layer: The input to the CNN is typically\nan image or a set of images. Each image is\nrepresented as a grid of pixels, where each pixel\ncontains color information (RGB values) or grayscale\nintensity.\nStep 2. Convolutional Layers: The CNN begins with\none or more convolutional layers. Each convolutional\nlayer consists of multiple filters/kernels, which are\nsmall matrices of weights. These filters are convolved\nwith the input data using a sliding window approach.\nThe filters detect specific features or patterns by\nperforming element-wise multiplication and\nsummation.\n', metadata={'source': '/content/CNN.pdf', 'file_path': '/content/CNN.pdf', 'page': 6, 'total_pages': 21}),
# ...

# %%
from langchain.chains import RetrievalQA

# Create the RetrievalQA chain
qa = RetrievalQA.from_chain_type(llm= raj_llm,
                                 chain_type="stuff",
                                 retriever=retriever,
                                 input_key='query',
                                 return_source_documents=True,
                                 )

# %%
qa("CNN key terms?")
# Out:
# {'query': 'CNN key terms?',
#  'result': 'Neural Network, Convolution, Convolutional Layer',
#  'source_documents': [Document(page_content='Convolutional\nNeural Network\n(CNN)\n', metadata={'source': '/content/CNN.pdf', 'file_path': '/content/CNN.pdf', 'page': 0, 'total_pages': 21}),
#   Document(page_content='Key Terms\nNeural Network: A computational model\ninspired by the structure and functionality of the\nhuman brain, consisting of interconnected nodes\n(neurons) that process and analyze information.\nConvolution: The mathematical operation of\napplying a filter/kernel to the input data, which\nhelps extract features by performing element-\nwise multiplication and summation.\nConvolutional Layer: The layer in a CNN that\napplies convolutional operations to the input data\nusing one or more filters/kernels.\n', metadata={'source': '/content/CNN.pdf', 'file_path': '/content/CNN.pdf', 'page': 2, 'total_pages': 21}),
# ...

# %%
query = "CNN key terms?"
response = qa(query)
response
# Out:
# {'query': 'CNN key terms?',
#  'result': 'The key terms of CNN are neural network, convolution, and convolutional layer.',
#  'source_documents': [Document(page_content='Convolutional\nNeural Network\n(CNN)\n', metadata={'source': '/content/CNN.pdf', 'file_path': '/content/CNN.pdf', 'page': 0, 'total_pages': 21}),
#   Document(page_content='Key Terms\nNeural Network: A computational model\ninspired by the structure and functionality of the\nhuman brain, consisting of interconnected nodes\n(neurons) that process and analyze information.\nConvolution: The mathematical operation of\napplying a filter/kernel to the input data, which\nhelps extract features by performing element-\nwise multiplication and summation.\nConvolutional Layer: The layer in a CNN that\napplies convolutional operations to the input data\nusing one or more filters/kernels.\n', metadata={'source': '/content/CNN.pdf', 'file_path': '/content/CNN.pdf', 'page': 2, 'total_pages': 21}),
# ...

# %%
response['result']
# Out:
# 'The key terms of CNN are neural network, convolution, and convolutional layer.'

# %%
query = "What is API?"
response = qa(query)
response
# Out:
# {'query': 'What is API?',
#  'result': "I don't know",
#  'source_documents': [Document(page_content='Example\n', metadata={'source': '/content/CNN.pdf', 'file_path': '/content/CNN.pdf', 'page': 5, 'total_pages': 21}),
#   Document(page_content='Key Terms\nFilter/Kernel: A small matrix of weights that is\nconvolved with the input data to produce a\nfeature map.\nFeature Map: The output of a convolutional layer,\nwhich represents the presence of specific\nfeatures in the input data.\nPooling: A downsampling operation that reduces\nthe spatial dimensions of the feature maps by\nselecting the most important or representative\nvalues.\n', metadata={'source': '/content/CNN.pdf', 'file_path': '/content/CNN.pdf', 'page': 3, 'total_pages': 21}),
# ...

# %%
from langchain.prompts import PromptTemplate

prompt_template = """Given the following context and a question, generate an answer based on this context only.
In the answer try to provide as much text as possible from "response" section in the source document context without making much changes.
If the answer is not found in the context, kindly state "I don't know." Don't try to make up an answer.

CONTEXT: {context}

QUESTION: {question}"""

PROMPT = PromptTemplate(
    template = prompt_template, input_variables=['context', 'question']
)

# %%
from langchain.chains import RetrievalQA

# Create the RetrievalQA chain
qa = RetrievalQA.from_chain_type(llm= raj_llm,
                                 chain_type="stuff",
                                 retriever=retriever,
                                 input_key='query',
                                 return_source_documents=True,
                                 chain_type_kwargs={'prompt': PROMPT})

# %%
query = "Who won the Cricket World Cup 2023 final?"
response = qa(query)
response['result']
# Out:
# "I don't know."
